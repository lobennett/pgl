# %% [markdown]
# ---
#
# Dialogs
#
# ---

# %%
# autoload
# %load_ext autoreload
# %autoreload 2

from pgl import pglChoose

# %% [markdown]
# ---
#
# Choose a single item from a list of strings
#
# ---

# %%
item = pglChoose.chooseItem(['item1', 'item2', 'item3'])
print(item)
# Out:
# None

# %% [markdown]
# ---
#
# Choose multiple items from a list of string
#
# ---

# %%
items = pglChoose.chooseItems(['item1', 'item2', 'item3'])
print(items)
# Out:
# ['item1', 'item2']

# %% [markdown]
# ---
#
# Scratch code for different metadata settings on traitlets for use with pglDialog.traitsDialog
#
# ---

# %%
temporalCalibration = List(Unicode(), hasPlotButton=True, buttonFunction="plotTemporalCalibration", default_value=['None'], help="Which temporal calibration to use")
settingsList = List(Instance(pglDisplaySettings), settingsListKey="name", traitDisplayName="Choose display", help="List of display settings")
buttons = [("Test", "testDisplay")]
serialize=False
     _size = Tuple(Int, Int, labels=("width","height"), property="size", enabled=False, allow_none=True, default_value=None, help="Image width x height")
   filesystem = Instance(AbstractFileSystem, allow_none=True, serialize=False, help="filesystem for serialization")
       childList = List(Instance(pglTraitSettings), settingsListKey="name", traitDisplayName="Select run(s)", multiSelect=True, maxRowsVisible=6, hasPlotButton=True, buttonFunction="display", help="Runs in session dir")
